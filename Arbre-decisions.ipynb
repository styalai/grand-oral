# %%
## Les arbres de decision
#Systeme basique d'IA, marche beacoup moins bien que des systeme plus avancer comme les réseau de neuronnes artificielle, le gradient boosting XGBoost (créer a partir d'arbre de decision), les SVM (Support Vector Machines). 
#Mais il a l'avantage d'etre tres interpretable. 
#Les arbres de decision sont des arbre binaire avec comme noeud un condition simple.
#Explample d'usage: prédire si un passager du titanic va survivre ou non. inputs: sexe, age, classe, output: 0=mort 1=vivant.
#Pour construire un arbre on prend les examples d'entrainement, et on va construire les noeud 1 a 1 en essayant toute les combinaison 
#d'input/de condition et prendre l'association qui va minimiser l'entropy.
#-> developper l'entropy de claude shannon
#E = - sum(n,i=1, proba_i * log2(proba_i)) # log 2 car on est en base 2: 0/1
